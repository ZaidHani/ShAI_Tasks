# %% [markdown]
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to ask about anything as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

plt.xlabel('x')
plt.ylabel('y')
plt.xticks([0,20,40,80,100])
plt.yticks([0,50,100,150,200])
plt.title('title')

plt.show()
# Out:
# C:\Users\MANAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig = plt.figure()
ax = add_axes([0,0,1,1])

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (4,3))

ax1.set_position([0,0,1,1])
ax2.set_position([0.2,0.5,.2,.2])

ax1.tick_params(labelsize=10)
ax2.tick_params(labelsize=7)

ax2.set_xticks([0,.2,.4,.6,.8,1])
ax2.set_yticks([0,.2,.4,.6,.8,1])

plt.show()

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (4,3))

ax1.set_position([0,0,1,1])
ax2.set_position([0.2,0.5,.2,.2])

ax1.set_xticks([0, 20, 40, 60, 80, 100])
ax1.set_yticks([0, 50, 100, 150, 200])

ax2.set_xticks([0, 20, 40, 60, 80, 100])
ax2.set_yticks([0, 50, 100, 150, 200])

ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax2.set_xlabel('X', size=7)
ax2.set_ylabel('Y', size=7)

ax1.tick_params(labelsize=10)
ax2.tick_params(labelsize=6)

ax1.plot(x,y, c='r')
ax2.plot(x,y, c='r')

plt.show()

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (4,3))

ax1.set_position([0,0,1,1])
ax2.set_position([0.2,0.5,.4,.4])
# Out:
# C:\Users\MANAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:93: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   func(*args, **kwargs)
# C:\Users\MANAL\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (4,3))

ax1.set_position([0,0,1,1])
ax2.set_position([0.2,0.5,.4,.4])

ax1.plot(x, z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.plot(x, y)
ax2.set_title('zoom')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')

ax2.tick_params(labelsize=7)

ax2.set_xlim((20,22))
ax2.set_ylim((30,50))

plt.show()

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig = plt.subplots(nrows=1, ncols=2, figsize = (4,3))

plt.show()

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize = (5,3))

axs[0].plot(x,y, linestyle='--', linewidth=2.2, c='b')
axs[1].plot(x,z, linewidth=2.2, c='r')

axs[0].set_xticks([0, 20, 40, 60, 80, 100])
axs[0].set_yticks([0, 50, 100, 150, 200])

axs[1].set_xticks([0, 20, 40, 60, 80, 100])
axs[1].set_yticks([0, 2000, 4000, 6000, 8000, 10000])

plt.show()

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize = (8,2))

axs[0].plot(x,y, linewidth=3, c='b')
axs[1].plot(x,z, linestyle='--', linewidth=1.8, c='r')

axs[0].set_xticks([0, 20, 40, 60, 80, 100])
axs[0].set_yticks([0, 50, 100, 150, 200])

axs[1].set_xticks([0, 20, 40, 60, 80, 100])
axs[1].set_yticks([0, 2000, 4000, 6000, 8000, 10000])

axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

plt.show()

# %% [markdown]
# # Great Job!

# %% [markdown]
# ## #shAI Club
